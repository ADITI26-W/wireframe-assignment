# %% [markdown]
# 1. Create a low-fidelity wireframe that demonstrates proper visual hierarchy, spacing, contrast, and alignment to ensure readability and usability.
#
# -![Screenshot 2026-01-18 141746.png](data:image/png;base64,...)
#
# Visual hierarchy is achieved by:
#
# - Largest text: “Login” (page heading)
#
# - Medium text: Email & Password labels
#
# - Smaller text: Helper text under input fields
#
# - Highest emphasis: Black “Login” button
#
# - Lower emphasis: Social login options
#
# Spacing & Alignment
#
# - Consistent vertical spacing between sections
#
# - Inputs and buttons are aligned vertically
#
# - Adequate padding inside input fields
#
# - Buttons have equal width → visual balance
#
# Color Palette Used (As Seen in Wireframe)
# - Primary Colors
#
# White – Background
#
# Black – Primary button (Login)
#
# Dark Gray – Main text
#
# - Secondary Colors
#
# Light Gray – Input borders
#
# Gray – Helper text
#
# Blue/Black icons – Social login buttons
#
# Contrast Ratio & WCAG Compliance
#
# | Element        | Text Color | Background       | WCAG |
# | -------------- | ---------- | ---------------- | ---- |
# | Heading        | Dark Gray  | White            | AAA  |
# | Labels         | Black      | White            | AAA  |
# | Helper Text    | Gray       | White            | AA   |
# | Login Button   | White      | Black            | AAA  |
# | Social Buttons | Dark text  | Light background | AA   |
#
# Accessibility Features
#
# - Clear labels for input fields
#
# - Placeholder text for guidance
#
# - Helper text for password rules
#
# - High contrast primary button
#
# - Large clickable buttons
#
# - Simple language
#
# Readability Testing
#
# - Minimum readable font size used
#
# - High contrast between text and background
#
# - Buttons clearly distinguishable
#
# - Links are visually separate
#
# Included in Submission:
#
# - Login page wireframe
#
# - Color palette with contrast analysis
#
# - Accessibility justification
#
# - Visual hierarchy explanation
